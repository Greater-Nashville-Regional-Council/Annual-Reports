# %%
import pandas as pd
import sqlite3 as sq
import matplotlib as mpl
from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np
import requests
pd.set_option('display.max_rows', 1000); pd.set_option('display.max_columns', 1000); pd.set_option('display.width', 1000)
pd.options.mode.chained_assignment = None
import pickle
import sqlite3 as sq

# %%
conn = sq.connect('../../Data-Pipelines/Outputs/CensusBureau.db')
sql_query = pd.read_sql('SELECT * FROM [CensusBureau_ACS5_2022_1]', conn)
ACS52022_1 = pd.DataFrame(sql_query)
sql_query = pd.read_sql('SELECT * FROM [CensusBureau_ACS5_2022_2]', conn)
ACS52022_2 = pd.DataFrame(sql_query)
ACS52022 = ACS52022_1.merge(ACS52022_2, on = ['NAME', 'GEO_ID', 'Source'])
ACS52022.drop(columns = 'Source', inplace = True)

# %%
data = ACS52022
thelist = ['Davidson County, Tennessee', 'Maury County, Tennessee', 'Robertson County, Tennessee', 
           'Rutherford County, Tennessee', 'Sumner County, Tennessee', 
           'Williamson County, Tennessee', 'Wilson County, Tennessee', 'MPO']
data = data.loc[data['NAME'].isin(thelist)].reset_index(drop = True)
cols = ['NAME', 'Population ACS', 'Male', 'Female', 'White Alone ACS', 'Black or African American Alone ACS', 'American Indian Alaska Native Alone ACS', 
        'Asian Alone ACS', 'Native Hawaiian Other Pacific Islander Alone ACS', 'Some Other Race Alone ACS', 'Two or More Races ACS', 'Hispanic or Latino ACS', 
        'Not Hispanic or Latino ACS' 
       ]
data = data[cols]

# %%
data.head()
# Out:
#                            NAME  Population ACS      Male    Female  White Alone ACS  Black or African American Alone ACS  American Indian Alaska Native Alone ACS  Asian Alone ACS  Native Hawaiian Other Pacific Islander Alone ACS  Some Other Race Alone ACS  Two or More Races ACS  Hispanic or Latino ACS  Not Hispanic or Latino ACS
# 0    Davidson County, Tennessee        709786.0  343836.0  365950.0         423888.0                             186862.0                                    965.0          25506.0                                             358.0                    27028.0                45179.0                 75237.0                    634549.0
# ...

# %%
data.to_csv('grantdownload.csv', index = False)
